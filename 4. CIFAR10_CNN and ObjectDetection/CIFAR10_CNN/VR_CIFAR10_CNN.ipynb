# %% [markdown]
# # Imports

# %%
import cv2
import pickle
import progressbar
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Using TensorFlow backend.

# %% [markdown]
# # Test Train dataset

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
num_classes = 10
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 5s 0us/step
# x_train shape: (50000, 32, 32, 3)
# x_test shape: (10000, 32, 32, 3)

# %% [markdown]
# # Defining the CNN model and architecuture

# %%
import progressbar
class progressBar:
    def __init__(self,percentage):
            self.bar = progressbar.ProgressBar(maxval=1, \
                                  widgets=[progressbar.Bar('=','[',']'), ' ', progressbar.Percentage()])
    def start(self):
        self.bar.start()
    
    def finish(self):
        self.bar.finish()
    
    def update(self,value):
        self.bar.update(value)

# %%
from time import time
from tensorflow.keras.callbacks import Callback

class TimingCallback(Callback):
    def __init__(self):
        self.logs=[]

    def on_epoch_begin(self,epoch, logs={}):
        self.starttime=time()

    def on_epoch_end(self,epoch, logs={}):
        self.logs.append(time()-self.starttime)

# %%
class CNN:

    def __init__(self,x_train,y_train,x_test,y_test):
        self.x_train = x_train
        self.y_train = y_train
        self.x_test = x_test
        self.y_test = y_test

    def set_architecture(self,structure,batch_normalization=False,activation='relu',learning_optimizer='rmsprop'):
        self.model = Sequential()

        if(structure[0][0]=='conv'):
            self.model.add(Conv2D(structure[0][1], (3, 3), padding='same',input_shape=self.x_train.shape[1:]))
            self.model.add(Activation(activation))
            if batch_normalization: self.model.add(BatchNormalization())

        for layer_type, size in structure[1:]:
            if(layer_type == 'conv'):
                self.model.add(Conv2D(size, (3, 3)))
                self.model.add(Activation(activation))
                if batch_normalization: self.model.add(BatchNormalization())
            
            if(layer_type == 'pool'):
                self.model.add(MaxPooling2D(pool_size=(size, size)))
                self.model.add(Dropout(0.25))

            if(layer_type == 'dense'):
                num_classes=10
                self.model.add(Flatten())
                self.model.add(Dense(size))
                self.model.add(Activation(activation))
                self.model.add(Dropout(0.5))
                self.model.add(Dense(num_classes))
                self.model.add(Activation('softmax'))

        if(learning_optimizer=='rmsprop'):
            # initiate RMSprop optimizer
            opt = keras.optimizers.RMSprop(learning_rate=0.0001, decay=1e-6)
        elif(learning_optimizer=='adagrad'):
            # initiate RMSprop optimizer
            opt = keras.optimizers.Adagrad(learning_rate=0.0001, decay=1e-6)
        elif(learning_optimizer=='adam'):
            # initiate RMSprop optimizer
            opt = keras.optimizers.Adam(learning_rate=0.0001, decay=1e-6)
            
        # Let's train the model using RMSprop
        self.model.compile(
            loss='categorical_crossentropy',
            optimizer=opt,
            metrics=['accuracy']
        )

    def compile(self,batch_size,epochs,call_back):
        self.history = self.model.fit(
            self.x_train, self.y_train,
            batch_size=batch_size,
            epochs=epochs,
            validation_data=(self.x_test, self.y_test),
            shuffle=True,
            callbacks=[call_back]
    )

    def evaluate(self):
        # Score trained model.
        scores = self.model.evaluate(self.x_test, self.y_test, verbose=1)
        print('Test loss:', scores[0])
        print('Test accuracy:', scores[1])

# %% [markdown]
# # Activation Function Comparision ( relu, tanh, sigmoid )

# %%
structure = [
    ('conv',32),
    ('pool',2),
    ('conv',64),
    ('pool',2),
    ('dense',512)
]

# %% [markdown]
# ### ReLu

# %%
call_back = TimingCallback()
relu_cnn = CNN(x_train,y_train,x_test,y_test)
relu_cnn.set_architecture(structure,activation='relu')
relu_cnn.compile(batch_size=100,epochs=30,call_back=call_back)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 6.2865 - accuracy: 0.1074 - val_loss: 2.3026 - val_accuracy: 0.0998
# Epoch 2/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 2.2916 - accuracy: 0.1159 - val_loss: 2.2056 - val_accuracy: 0.1629
# Epoch 3/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.2477 - accuracy: 0.1382 - val_loss: 2.1585 - val_accuracy: 0.1843
# Epoch 4/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.2097 - accuracy: 0.1581 - val_loss: 2.0749 - val_accuracy: 0.2357
# Epoch 5/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.0986 - accuracy: 0.1982 - val_loss: 1.8585 - val_accuracy: 0.3290
# Epoch 6/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.9667 - accuracy: 0.2528 - val_loss: 1.7136 - val_accuracy: 0.3943
# Epoch 7/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.8735 - accuracy: 0.2956 - val_loss: 1.6601 - val_accuracy: 0.4146
# Epoch 8/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.7828 - accuracy: 0.3342 - val_loss: 1.5751 - val_accuracy: 0.4341
# Epoch 9/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.7048 - accuracy: 0.3730 - val_loss: 1.5413 - val_accuracy: 0.4533
# Epoch 10/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.6367 - accuracy: 0.4008 - val_loss: 1.4958 - val_accuracy: 0.4760
# Epoch 11/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.5794 - accuracy: 0.4266 - val_loss: 1.4416 - val_accuracy: 0.4979
# Epoch 12/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.5258 - accuracy: 0.4469 - val_loss: 1.4313 - val_accuracy: 0.5004
# Epoch 13/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.4835 - accuracy: 0.4656 - val_loss: 1.3943 - val_accuracy: 0.5222
# Epoch 14/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.4431 - accuracy: 0.4778 - val_loss: 1.4176 - val_accuracy: 0.5107
# Epoch 15/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.4089 - accuracy: 0.4958 - val_loss: 1.3508 - val_accuracy: 0.5412
# Epoch 16/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.3716 - accuracy: 0.5111 - val_loss: 1.3360 - val_accuracy: 0.5408
# Epoch 17/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.3560 - accuracy: 0.5190 - val_loss: 1.3271 - val_accuracy: 0.5400
# Epoch 18/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.3268 - accuracy: 0.5293 - val_loss: 1.3145 - val_accuracy: 0.5587
# Epoch 19/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.2998 - accuracy: 0.5421 - val_loss: 1.2975 - val_accuracy: 0.5665
# Epoch 20/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.2755 - accuracy: 0.5519 - val_loss: 1.2939 - val_accuracy: 0.5645
# Epoch 21/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.2632 - accuracy: 0.5564 - val_loss: 1.2914 - val_accuracy: 0.5599
# Epoch 22/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 1.2485 - accuracy: 0.5620 - val_loss: 1.2685 - val_accuracy: 0.5691
# Epoch 23/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.2310 - accuracy: 0.5697 - val_loss: 1.2502 - val_accuracy: 0.5831
# Epoch 24/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.2180 - accuracy: 0.5758 - val_loss: 1.2575 - val_accuracy: 0.5927
# Epoch 25/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.1944 - accuracy: 0.5846 - val_loss: 1.2380 - val_accuracy: 0.5771
# Epoch 26/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.1870 - accuracy: 0.5868 - val_loss: 1.2519 - val_accuracy: 0.5929
# Epoch 27/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.1750 - accuracy: 0.5906 - val_loss: 1.2611 - val_accuracy: 0.5847
# Epoch 28/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.1636 - accuracy: 0.5977 - val_loss: 1.2697 - val_accuracy: 0.5886
# Epoch 29/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.1552 - accuracy: 0.5992 - val_loss: 1.2724 - val_accuracy: 0.5972
# Epoch 30/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.1433 - accuracy: 0.6044 - val_loss: 1.2339 - val_accuracy: 0.6072

# %% [markdown]
# ### Tanh

# %%
call_back = TimingCallback()
tanh_cnn = CNN(x_train,y_train,x_test,y_test)
tanh_cnn.set_architecture(structure,activation='tanh')  
tanh_cnn.compile(batch_size=100,epochs=30,call_back=call_back)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 1.9068 - accuracy: 0.3345 - val_loss: 2.0960 - val_accuracy: 0.3348
# Epoch 2/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 1.5815 - accuracy: 0.4480 - val_loss: 2.1361 - val_accuracy: 0.3516
# Epoch 3/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.4858 - accuracy: 0.4784 - val_loss: 2.1372 - val_accuracy: 0.3521
# Epoch 4/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 1.4265 - accuracy: 0.4972 - val_loss: 2.1179 - val_accuracy: 0.3678
# Epoch 5/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.3878 - accuracy: 0.5132 - val_loss: 2.1409 - val_accuracy: 0.3677
# Epoch 6/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.3473 - accuracy: 0.5253 - val_loss: 1.9401 - val_accuracy: 0.4012
# Epoch 7/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.3149 - accuracy: 0.5330 - val_loss: 1.8144 - val_accuracy: 0.4314
# Epoch 8/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.2904 - accuracy: 0.5433 - val_loss: 1.8306 - val_accuracy: 0.4339
# Epoch 9/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.2702 - accuracy: 0.5498 - val_loss: 1.8826 - val_accuracy: 0.4234
# Epoch 10/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.2503 - accuracy: 0.5574 - val_loss: 1.7355 - val_accuracy: 0.4464
# Epoch 11/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.2194 - accuracy: 0.5664 - val_loss: 1.6819 - val_accuracy: 0.4581
# Epoch 12/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.2053 - accuracy: 0.5728 - val_loss: 1.5667 - val_accuracy: 0.4869
# Epoch 13/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.1797 - accuracy: 0.5810 - val_loss: 1.6785 - val_accuracy: 0.4659
# Epoch 14/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.1646 - accuracy: 0.5868 - val_loss: 1.5924 - val_accuracy: 0.4783
# Epoch 15/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.1491 - accuracy: 0.5898 - val_loss: 1.4468 - val_accuracy: 0.5216
# Epoch 16/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.1319 - accuracy: 0.5996 - val_loss: 1.4860 - val_accuracy: 0.5118
# Epoch 17/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.1159 - accuracy: 0.6037 - val_loss: 1.5792 - val_accuracy: 0.4885
# Epoch 18/30
# 50000/50000 [==============================] - 91s 2ms/step - loss: 1.0963 - accuracy: 0.6102 - val_loss: 1.3423 - val_accuracy: 0.5462
# Epoch 19/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.0850 - accuracy: 0.6140 - val_loss: 1.3186 - val_accuracy: 0.5496
# Epoch 20/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.0733 - accuracy: 0.6192 - val_loss: 1.2956 - val_accuracy: 0.5569
# Epoch 21/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.0563 - accuracy: 0.6233 - val_loss: 1.3081 - val_accuracy: 0.5589
# Epoch 22/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.0428 - accuracy: 0.6306 - val_loss: 1.3327 - val_accuracy: 0.5532
# Epoch 23/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.0335 - accuracy: 0.6331 - val_loss: 1.1677 - val_accuracy: 0.5968
# Epoch 24/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.0194 - accuracy: 0.6386 - val_loss: 1.2214 - val_accuracy: 0.5804
# Epoch 25/30
# 50000/50000 [==============================] - 92s 2ms/step - loss: 1.0117 - accuracy: 0.6425 - val_loss: 1.2254 - val_accuracy: 0.5809
# Epoch 26/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.9981 - accuracy: 0.6459 - val_loss: 1.1643 - val_accuracy: 0.5982
# Epoch 27/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.9848 - accuracy: 0.6493 - val_loss: 1.1591 - val_accuracy: 0.6046
# Epoch 28/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.9771 - accuracy: 0.6549 - val_loss: 1.1986 - val_accuracy: 0.5873
# Epoch 29/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.9651 - accuracy: 0.6589 - val_loss: 1.1533 - val_accuracy: 0.6035
# Epoch 30/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 0.9537 - accuracy: 0.6631 - val_loss: 1.2099 - val_accuracy: 0.5852

# %% [markdown]
# ### Sigmoid

# %%
call_back = TimingCallback()
sigmoid_cnn = CNN(x_train,y_train,x_test,y_test)
sigmoid_cnn.set_architecture(structure,activation='sigmoid')  
sigmoid_cnn.compile(batch_size=100,epochs=30,call_back=call_back)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 2.2119 - accuracy: 0.1671 - val_loss: 1.8992 - val_accuracy: 0.3368
# Epoch 2/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.8629 - accuracy: 0.3127 - val_loss: 1.7021 - val_accuracy: 0.3896
# Epoch 3/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.7309 - accuracy: 0.3688 - val_loss: 1.6114 - val_accuracy: 0.4214
# Epoch 4/30
# 50000/50000 [==============================] - 88s 2ms/step - loss: 1.6571 - accuracy: 0.3963 - val_loss: 1.5598 - val_accuracy: 0.4328
# Epoch 5/30
# 50000/50000 [==============================] - 88s 2ms/step - loss: 1.6053 - accuracy: 0.4177 - val_loss: 1.5082 - val_accuracy: 0.4562
# Epoch 6/30
# 50000/50000 [==============================] - 88s 2ms/step - loss: 1.5637 - accuracy: 0.4330 - val_loss: 1.4714 - val_accuracy: 0.4658
# Epoch 7/30
# 50000/50000 [==============================] - 88s 2ms/step - loss: 1.5261 - accuracy: 0.4474 - val_loss: 1.4352 - val_accuracy: 0.4814
# Epoch 8/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.4913 - accuracy: 0.4605 - val_loss: 1.4018 - val_accuracy: 0.4893
# Epoch 9/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.4592 - accuracy: 0.4722 - val_loss: 1.3658 - val_accuracy: 0.5042
# Epoch 10/30
# 50000/50000 [==============================] - 90s 2ms/step - loss: 1.4337 - accuracy: 0.4841 - val_loss: 1.3501 - val_accuracy: 0.5077
# Epoch 11/30
# 50000/50000 [==============================] - 90s 2ms/step - loss: 1.4095 - accuracy: 0.4910 - val_loss: 1.3634 - val_accuracy: 0.5052
# Epoch 12/30
# 50000/50000 [==============================] - 90s 2ms/step - loss: 1.3855 - accuracy: 0.4999 - val_loss: 1.2977 - val_accuracy: 0.5302
# Epoch 13/30
# 50000/50000 [==============================] - 90s 2ms/step - loss: 1.3593 - accuracy: 0.5083 - val_loss: 1.2777 - val_accuracy: 0.5370
# Epoch 14/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.3380 - accuracy: 0.5184 - val_loss: 1.2663 - val_accuracy: 0.5405
# Epoch 15/30
# 50000/50000 [==============================] - 90s 2ms/step - loss: 1.3178 - accuracy: 0.5256 - val_loss: 1.2281 - val_accuracy: 0.5571
# Epoch 16/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.3020 - accuracy: 0.5312 - val_loss: 1.2120 - val_accuracy: 0.5628
# Epoch 17/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.2871 - accuracy: 0.5356 - val_loss: 1.2046 - val_accuracy: 0.5641
# Epoch 18/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.2722 - accuracy: 0.5430 - val_loss: 1.1917 - val_accuracy: 0.5720
# Epoch 19/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.2567 - accuracy: 0.5476 - val_loss: 1.2239 - val_accuracy: 0.5645
# Epoch 20/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.2421 - accuracy: 0.5549 - val_loss: 1.1551 - val_accuracy: 0.5820
# Epoch 21/30
# 50000/50000 [==============================] - 90s 2ms/step - loss: 1.2283 - accuracy: 0.5584 - val_loss: 1.1438 - val_accuracy: 0.5886
# Epoch 22/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.2185 - accuracy: 0.5622 - val_loss: 1.1364 - val_accuracy: 0.5910
# Epoch 23/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.2084 - accuracy: 0.5667 - val_loss: 1.1296 - val_accuracy: 0.5931
# Epoch 24/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.1947 - accuracy: 0.5731 - val_loss: 1.1240 - val_accuracy: 0.5949
# Epoch 25/30
# 50000/50000 [==============================] - 90s 2ms/step - loss: 1.1827 - accuracy: 0.5765 - val_loss: 1.0984 - val_accuracy: 0.6059
# Epoch 26/30
# 50000/50000 [==============================] - 90s 2ms/step - loss: 1.1751 - accuracy: 0.5802 - val_loss: 1.1061 - val_accuracy: 0.6054
# Epoch 27/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.1623 - accuracy: 0.5850 - val_loss: 1.0858 - val_accuracy: 0.6123
# Epoch 28/30
# 50000/50000 [==============================] - 93s 2ms/step - loss: 1.1545 - accuracy: 0.5878 - val_loss: 1.0800 - val_accuracy: 0.6138
# Epoch 29/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.1396 - accuracy: 0.5947 - val_loss: 1.0624 - val_accuracy: 0.6212
# Epoch 30/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.1321 - accuracy: 0.5961 - val_loss: 1.0875 - val_accuracy: 0.6143

# %%
relu_loss = relu_cnn.history.history['loss']
tanh_loss = tanh_cnn.history.history['loss']
sigmoid_loss = sigmoid_cnn.history.history['loss']
epochs = range(1, len(relu_loss) + 1)
# plt.figure(figsize=(20,10))
plt.plot(epochs, relu_loss, 'r', label='relu training loss')
plt.plot(epochs, tanh_loss, 'y', label='tanh training loss')
plt.plot(epochs, sigmoid_loss, 'g', label='sigmoid training loss')
plt.title('relu vs tanh vs sigmoid training loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid()
plt.legend()
# plt.savefig('training loss comparision')
plt.show()

# %%
relu_acc = relu_cnn.history.history['val_accuracy']
tanh_acc = tanh_cnn.history.history['val_accuracy']
sigmoid_acc = sigmoid_cnn.history.history['val_accuracy']
# plt.figure(figsize=(20,10))
plt.plot(epochs, relu_acc, 'r', label='relu validation acc')
plt.plot(epochs, tanh_acc, 'y', label='tanh validation acc')
plt.plot(epochs, sigmoid_acc, 'g', label='sigmoid validation acc')
plt.title('relu vs tanh vs sigmoid validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
# plt.savefig('validation accuracy comparision')
plt.show()

# %% [markdown]
# # Tunning Batch Normalization Hyper-parameter

# %% [markdown]
# ### Sigmoid With Batch Normalization

# %%
call_back = TimingCallback()
sigmoid_cnn = CNN(x_train,y_train,x_test,y_test)
sigmoid_cnn.set_architecture(structure,activation='sigmoid',batch_normalization=True)  
sigmoid_cnn.compile(batch_size=100,epochs=30,call_back=call_back)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 118s 2ms/step - loss: 1.8002 - accuracy: 0.3477 - val_loss: 1.5049 - val_accuracy: 0.4686
# Epoch 2/30
# 50000/50000 [==============================] - 117s 2ms/step - loss: 1.5049 - accuracy: 0.4579 - val_loss: 1.3519 - val_accuracy: 0.5188
# Epoch 3/30
# 50000/50000 [==============================] - 118s 2ms/step - loss: 1.3790 - accuracy: 0.5055 - val_loss: 1.2561 - val_accuracy: 0.5478
# Epoch 4/30
# 50000/50000 [==============================] - 118s 2ms/step - loss: 1.3023 - accuracy: 0.5330 - val_loss: 1.1834 - val_accuracy: 0.5728
# Epoch 5/30
# 50000/50000 [==============================] - 118s 2ms/step - loss: 1.2488 - accuracy: 0.5537 - val_loss: 1.1675 - val_accuracy: 0.5732
# Epoch 6/30
# 50000/50000 [==============================] - 118s 2ms/step - loss: 1.2101 - accuracy: 0.5703 - val_loss: 1.1397 - val_accuracy: 0.5946
# Epoch 7/30
# 50000/50000 [==============================] - 117s 2ms/step - loss: 1.1755 - accuracy: 0.5795 - val_loss: 1.1057 - val_accuracy: 0.6106
# Epoch 8/30
# 50000/50000 [==============================] - 118s 2ms/step - loss: 1.1458 - accuracy: 0.5920 - val_loss: 1.1009 - val_accuracy: 0.6057
# Epoch 9/30
# 50000/50000 [==============================] - 118s 2ms/step - loss: 1.1161 - accuracy: 0.6054 - val_loss: 1.0552 - val_accuracy: 0.6310
# Epoch 10/30
# 50000/50000 [==============================] - 119s 2ms/step - loss: 1.0963 - accuracy: 0.6110 - val_loss: 1.0581 - val_accuracy: 0.6227
# Epoch 11/30
# 50000/50000 [==============================] - 118s 2ms/step - loss: 1.0719 - accuracy: 0.6203 - val_loss: 1.0677 - val_accuracy: 0.6223
# Epoch 12/30
# 50000/50000 [==============================] - 119s 2ms/step - loss: 1.0552 - accuracy: 0.6282 - val_loss: 1.0445 - val_accuracy: 0.6239
# Epoch 13/30
# 50000/50000 [==============================] - 119s 2ms/step - loss: 1.0357 - accuracy: 0.6330 - val_loss: 1.0689 - val_accuracy: 0.6317
# Epoch 14/30
# 50000/50000 [==============================] - 119s 2ms/step - loss: 1.0155 - accuracy: 0.6421 - val_loss: 1.0011 - val_accuracy: 0.6463
# Epoch 15/30
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.9991 - accuracy: 0.6482 - val_loss: 0.9754 - val_accuracy: 0.6529
# Epoch 16/30
# 50000/50000 [==============================] - 120s 2ms/step - loss: 0.9836 - accuracy: 0.6531 - val_loss: 1.0463 - val_accuracy: 0.6391
# Epoch 17/30
# 50000/50000 [==============================] - 120s 2ms/step - loss: 0.9679 - accuracy: 0.6583 - val_loss: 0.9961 - val_accuracy: 0.6477
# Epoch 18/30
# 50000/50000 [==============================] - 120s 2ms/step - loss: 0.9602 - accuracy: 0.6632 - val_loss: 0.9841 - val_accuracy: 0.6578
# Epoch 19/30
# 50000/50000 [==============================] - 120s 2ms/step - loss: 0.9429 - accuracy: 0.6673 - val_loss: 0.9532 - val_accuracy: 0.6608
# Epoch 20/30
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.9288 - accuracy: 0.6736 - val_loss: 0.9332 - val_accuracy: 0.6746
# Epoch 21/30
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.9136 - accuracy: 0.6780 - val_loss: 0.9283 - val_accuracy: 0.6734
# Epoch 22/30
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.9039 - accuracy: 0.6830 - val_loss: 0.9461 - val_accuracy: 0.6693
# Epoch 23/30
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.8919 - accuracy: 0.6853 - val_loss: 0.9399 - val_accuracy: 0.6670
# Epoch 24/30
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.8760 - accuracy: 0.6940 - val_loss: 0.9175 - val_accuracy: 0.6823
# Epoch 25/30
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.8695 - accuracy: 0.6951 - val_loss: 0.9290 - val_accuracy: 0.6795
# Epoch 26/30
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.8520 - accuracy: 0.6996 - val_loss: 0.8976 - val_accuracy: 0.6884
# Epoch 27/30
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.8438 - accuracy: 0.7042 - val_loss: 0.8808 - val_accuracy: 0.6929
# Epoch 28/30
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.8348 - accuracy: 0.7086 - val_loss: 0.8715 - val_accuracy: 0.6953
# Epoch 29/30
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.8196 - accuracy: 0.7142 - val_loss: 0.8903 - val_accuracy: 0.6907
# Epoch 30/30
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.8172 - accuracy: 0.7149 - val_loss: 0.8651 - val_accuracy: 0.6958

# %%
loss = sigmoid_cnn.history.history['loss']
val_loss = sigmoid_cnn.history.history['val_loss']
epochs = range(1, len(loss) + 1)
# plt.figure(figsize=(20,10))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
# plt.savefig('sigmoid_wth_normalization_loss')
plt.show()

# %%
acc = sigmoid_cnn.history.history['accuracy']
val_acc = sigmoid_cnn.history.history['val_accuracy']
# plt.figure(figsize=(20,10))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
# plt.savefig('sigmoid_wth_normalization_acc')
plt.show()

# %% [markdown]
# ### Sigmoid Without Batch Normalization

# %%
call_back = TimingCallback()
sigmoid_cnn_without_normalization = CNN(x_train,y_train,x_test,y_test)
sigmoid_cnn_without_normalization.set_architecture(structure,activation='sigmoid',batch_normalization=False)  
sigmoid_cnn_without_normalization.compile(batch_size=100,epochs=30,call_back=call_back)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 88s 2ms/step - loss: 2.1865 - accuracy: 0.1814 - val_loss: 1.9364 - val_accuracy: 0.2890
# Epoch 2/30
# 50000/50000 [==============================] - 88s 2ms/step - loss: 1.8688 - accuracy: 0.3117 - val_loss: 1.7076 - val_accuracy: 0.3841
# Epoch 3/30
# 50000/50000 [==============================] - 88s 2ms/step - loss: 1.7375 - accuracy: 0.3679 - val_loss: 1.6229 - val_accuracy: 0.4077
# Epoch 4/30
# 50000/50000 [==============================] - 88s 2ms/step - loss: 1.6605 - accuracy: 0.3984 - val_loss: 1.5543 - val_accuracy: 0.4346
# Epoch 5/30
# 50000/50000 [==============================] - 88s 2ms/step - loss: 1.6016 - accuracy: 0.4191 - val_loss: 1.4885 - val_accuracy: 0.4561
# Epoch 6/30
# 50000/50000 [==============================] - 90s 2ms/step - loss: 1.5500 - accuracy: 0.4392 - val_loss: 1.4620 - val_accuracy: 0.4621
# Epoch 7/30
# 50000/50000 [==============================] - 90s 2ms/step - loss: 1.5063 - accuracy: 0.4537 - val_loss: 1.4227 - val_accuracy: 0.4800
# Epoch 8/30
# 50000/50000 [==============================] - 90s 2ms/step - loss: 1.4697 - accuracy: 0.4662 - val_loss: 1.3734 - val_accuracy: 0.5013
# Epoch 9/30
# 50000/50000 [==============================] - 90s 2ms/step - loss: 1.4313 - accuracy: 0.4814 - val_loss: 1.3330 - val_accuracy: 0.5123
# Epoch 10/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.4010 - accuracy: 0.4929 - val_loss: 1.3057 - val_accuracy: 0.5208
# Epoch 11/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.3777 - accuracy: 0.5030 - val_loss: 1.2919 - val_accuracy: 0.5262
# Epoch 12/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.3537 - accuracy: 0.5121 - val_loss: 1.2736 - val_accuracy: 0.5412
# Epoch 13/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.3320 - accuracy: 0.5191 - val_loss: 1.2348 - val_accuracy: 0.5564
# Epoch 14/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.3105 - accuracy: 0.5268 - val_loss: 1.2178 - val_accuracy: 0.5605
# Epoch 15/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.2931 - accuracy: 0.5357 - val_loss: 1.2122 - val_accuracy: 0.5639
# Epoch 16/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.2762 - accuracy: 0.5421 - val_loss: 1.1875 - val_accuracy: 0.5704
# Epoch 17/30
# 50000/50000 [==============================] - 90s 2ms/step - loss: 1.2597 - accuracy: 0.5483 - val_loss: 1.1852 - val_accuracy: 0.5733
# Epoch 18/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.2432 - accuracy: 0.5524 - val_loss: 1.1639 - val_accuracy: 0.5798
# Epoch 19/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 1.2299 - accuracy: 0.5577 - val_loss: 1.1438 - val_accuracy: 0.5894
# Epoch 20/30
# 50000/50000 [==============================] - 94s 2ms/step - loss: 1.2201 - accuracy: 0.5637 - val_loss: 1.1608 - val_accuracy: 0.5826
# Epoch 21/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.2029 - accuracy: 0.5695 - val_loss: 1.1557 - val_accuracy: 0.5820
# Epoch 22/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.1959 - accuracy: 0.5713 - val_loss: 1.1096 - val_accuracy: 0.6008
# Epoch 23/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.1809 - accuracy: 0.5770 - val_loss: 1.1100 - val_accuracy: 0.6025
# Epoch 24/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.1694 - accuracy: 0.5824 - val_loss: 1.0841 - val_accuracy: 0.6103
# Epoch 25/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.1603 - accuracy: 0.5861 - val_loss: 1.0993 - val_accuracy: 0.6060
# Epoch 26/30
# 50000/50000 [==============================] - 92s 2ms/step - loss: 1.1501 - accuracy: 0.5889 - val_loss: 1.0713 - val_accuracy: 0.6166
# Epoch 27/30
# 50000/50000 [==============================] - 88s 2ms/step - loss: 1.1391 - accuracy: 0.5916 - val_loss: 1.0601 - val_accuracy: 0.6198
# Epoch 28/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.1268 - accuracy: 0.5986 - val_loss: 1.0590 - val_accuracy: 0.6208
# Epoch 29/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.1214 - accuracy: 0.6002 - val_loss: 1.0820 - val_accuracy: 0.6129
# Epoch 30/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.1102 - accuracy: 0.6048 - val_loss: 1.0353 - val_accuracy: 0.6291

# %%
loss = sigmoid_cnn_without_normalization.history.history['loss']
val_loss = sigmoid_cnn_without_normalization.history.history['val_loss']
epochs = range(1, len(loss) + 1)
# plt.figure(figsize=(20,10))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
# plt.savefig('sigmoid_wthout_normalization_loss')
plt.show()

# %%
acc = sigmoid_cnn_without_normalization.history.history['accuracy']
val_acc = sigmoid_cnn_without_normalization.history.history['val_accuracy']
# plt.figure(figsize=(20,10))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
# plt.savefig('sigmoid_wthout_normalization_acc')
plt.show()

# %% [markdown]
# ### Comparision graph of with and without Batch Normalization

# %%
# acc_without = sigmoid_cnn_without_normalization.history.history['accuracy']
val_acc_with = sigmoid_cnn.history.history['val_accuracy']
val_acc_without = sigmoid_cnn_without_normalization.history.history['val_accuracy']
# plt.figure(figsize=(20,10))
plt.plot(epochs, val_acc_with, 'y', label='Validation acc with batch norm')
plt.plot(epochs, val_acc_without, 'r', label='Validation acc without batch norm')
plt.title('Validation accuracy comparision for batch normalization')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
# plt.savefig('sigmoid_comparision_with_and_wthout_normalization_acc')
plt.show()

# %% [markdown]
# # Adaptive Learning Rates

# %% [markdown]
# ### RmsProp

# %%
call_back = TimingCallback()
rmsprop_cnn = CNN(x_train,y_train,x_test,y_test)
rmsprop_cnn.set_architecture(structure,learning_optimizer='rmsprop')
rmsprop_cnn.compile(batch_size=100,epochs=30,call_back=call_back)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 5.2381 - accuracy: 0.1188 - val_loss: 2.2246 - val_accuracy: 0.1615
# Epoch 2/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 2.2062 - accuracy: 0.1644 - val_loss: 2.0395 - val_accuracy: 0.2605
# Epoch 3/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 2.0918 - accuracy: 0.2178 - val_loss: 1.9061 - val_accuracy: 0.3036
# Epoch 4/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.9789 - accuracy: 0.2567 - val_loss: 1.7672 - val_accuracy: 0.3705
# Epoch 5/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.8741 - accuracy: 0.3003 - val_loss: 1.6761 - val_accuracy: 0.4040
# Epoch 6/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.7912 - accuracy: 0.3340 - val_loss: 1.6067 - val_accuracy: 0.4436
# Epoch 7/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.7096 - accuracy: 0.3749 - val_loss: 1.5429 - val_accuracy: 0.4568
# Epoch 8/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.6253 - accuracy: 0.4060 - val_loss: 1.4900 - val_accuracy: 0.4861
# Epoch 9/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.5728 - accuracy: 0.4317 - val_loss: 1.4351 - val_accuracy: 0.4939
# Epoch 10/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.5165 - accuracy: 0.4551 - val_loss: 1.3908 - val_accuracy: 0.5195
# Epoch 11/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 1.4657 - accuracy: 0.4756 - val_loss: 1.3962 - val_accuracy: 0.5228
# Epoch 12/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.4280 - accuracy: 0.4896 - val_loss: 1.3548 - val_accuracy: 0.5361
# Epoch 13/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.3864 - accuracy: 0.5041 - val_loss: 1.3500 - val_accuracy: 0.5442
# Epoch 14/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.3502 - accuracy: 0.5208 - val_loss: 1.2874 - val_accuracy: 0.5666
# Epoch 15/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.3202 - accuracy: 0.5310 - val_loss: 1.3097 - val_accuracy: 0.5635
# Epoch 16/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.2999 - accuracy: 0.5410 - val_loss: 1.2847 - val_accuracy: 0.5677
# Epoch 17/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.2657 - accuracy: 0.5569 - val_loss: 1.2338 - val_accuracy: 0.5899
# Epoch 18/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.2416 - accuracy: 0.5624 - val_loss: 1.2346 - val_accuracy: 0.6014
# Epoch 19/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.2243 - accuracy: 0.5677 - val_loss: 1.2027 - val_accuracy: 0.6104
# Epoch 20/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.2045 - accuracy: 0.5776 - val_loss: 1.2116 - val_accuracy: 0.6123
# Epoch 21/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.1880 - accuracy: 0.5851 - val_loss: 1.2806 - val_accuracy: 0.5971
# Epoch 22/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.1702 - accuracy: 0.5921 - val_loss: 1.1919 - val_accuracy: 0.6053
# Epoch 23/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.1549 - accuracy: 0.5973 - val_loss: 1.2146 - val_accuracy: 0.6151
# Epoch 24/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.1378 - accuracy: 0.6054 - val_loss: 1.1683 - val_accuracy: 0.6261
# Epoch 25/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.1301 - accuracy: 0.6093 - val_loss: 1.1759 - val_accuracy: 0.6182
# Epoch 26/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.1114 - accuracy: 0.6176 - val_loss: 1.1539 - val_accuracy: 0.6280
# Epoch 27/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.1052 - accuracy: 0.6198 - val_loss: 1.1153 - val_accuracy: 0.6464
# Epoch 28/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.0959 - accuracy: 0.6217 - val_loss: 1.1945 - val_accuracy: 0.6347
# Epoch 29/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.0835 - accuracy: 0.6272 - val_loss: 1.1394 - val_accuracy: 0.6478
# Epoch 30/30
# 50000/50000 [==============================] - 84s 2ms/step - loss: 1.0752 - accuracy: 0.6319 - val_loss: 1.1468 - val_accuracy: 0.6357

# %% [markdown]
# ### AdaGrad

# %%
call_back = TimingCallback()
adagrad_cnn = CNN(x_train,y_train,x_test,y_test)
adagrad_cnn.set_architecture(structure,learning_optimizer='adagrad')
adagrad_cnn.compile(batch_size=100,epochs=30,call_back=call_back)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 40.4319 - accuracy: 0.1185 - val_loss: 4.1122 - val_accuracy: 0.1526
# Epoch 2/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 11.7699 - accuracy: 0.1211 - val_loss: 2.3781 - val_accuracy: 0.1318
# Epoch 3/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 6.0357 - accuracy: 0.1142 - val_loss: 2.3093 - val_accuracy: 0.1093
# Epoch 4/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 4.1447 - accuracy: 0.1121 - val_loss: 2.3053 - val_accuracy: 0.1027
# Epoch 5/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 3.4300 - accuracy: 0.1126 - val_loss: 2.3045 - val_accuracy: 0.1004
# Epoch 6/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 3.0961 - accuracy: 0.1111 - val_loss: 2.3037 - val_accuracy: 0.1002
# Epoch 7/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.8767 - accuracy: 0.1101 - val_loss: 2.3032 - val_accuracy: 0.1010
# Epoch 8/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.7406 - accuracy: 0.1081 - val_loss: 2.3029 - val_accuracy: 0.1008
# Epoch 9/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.6804 - accuracy: 0.1065 - val_loss: 2.3028 - val_accuracy: 0.1004
# Epoch 10/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.6186 - accuracy: 0.1058 - val_loss: 2.3028 - val_accuracy: 0.1002
# Epoch 11/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.5642 - accuracy: 0.1069 - val_loss: 2.3027 - val_accuracy: 0.1001
# Epoch 12/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.5393 - accuracy: 0.1058 - val_loss: 2.3027 - val_accuracy: 0.1002
# Epoch 13/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.5163 - accuracy: 0.1038 - val_loss: 2.3027 - val_accuracy: 0.1003
# Epoch 14/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.4914 - accuracy: 0.1061 - val_loss: 2.3027 - val_accuracy: 0.1004
# Epoch 15/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.4778 - accuracy: 0.1044 - val_loss: 2.3027 - val_accuracy: 0.1003
# Epoch 16/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.4624 - accuracy: 0.1037 - val_loss: 2.3026 - val_accuracy: 0.1003
# Epoch 17/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.4549 - accuracy: 0.1041 - val_loss: 2.3026 - val_accuracy: 0.1003
# Epoch 18/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.4307 - accuracy: 0.1027 - val_loss: 2.3026 - val_accuracy: 0.1002
# Epoch 19/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.4239 - accuracy: 0.1034 - val_loss: 2.3026 - val_accuracy: 0.1003
# Epoch 20/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.4163 - accuracy: 0.1031 - val_loss: 2.3026 - val_accuracy: 0.1003
# Epoch 21/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 2.4118 - accuracy: 0.1023 - val_loss: 2.3026 - val_accuracy: 0.1005
# Epoch 22/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 2.4067 - accuracy: 0.1036 - val_loss: 2.3026 - val_accuracy: 0.1005
# Epoch 23/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 2.3976 - accuracy: 0.1027 - val_loss: 2.3026 - val_accuracy: 0.1005
# Epoch 24/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 2.3969 - accuracy: 0.1035 - val_loss: 2.3026 - val_accuracy: 0.1005
# Epoch 25/30
# 50000/50000 [==============================] - 89s 2ms/step - loss: 2.3906 - accuracy: 0.1033 - val_loss: 2.3026 - val_accuracy: 0.1005
# Epoch 26/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 2.3800 - accuracy: 0.1035 - val_loss: 2.3026 - val_accuracy: 0.1004
# Epoch 27/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 2.3736 - accuracy: 0.1046 - val_loss: 2.3026 - val_accuracy: 0.1003
# Epoch 28/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 2.3740 - accuracy: 0.1026 - val_loss: 2.3026 - val_accuracy: 0.1002
# Epoch 29/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 2.3762 - accuracy: 0.1022 - val_loss: 2.3026 - val_accuracy: 0.1002
# Epoch 30/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 2.3701 - accuracy: 0.1024 - val_loss: 2.3026 - val_accuracy: 0.1002

# %% [markdown]
# ### Adam

# %%
call_back = TimingCallback()
adam_cnn = CNN(x_train,y_train,x_test,y_test)
adam_cnn.set_architecture(structure,learning_optimizer='adam')
adam_cnn.compile(batch_size=100,epochs=30,call_back=call_back)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 87s 2ms/step - loss: 5.9783 - accuracy: 0.1164 - val_loss: 2.3004 - val_accuracy: 0.1024
# Epoch 2/30
# 50000/50000 [==============================] - 91s 2ms/step - loss: 2.3057 - accuracy: 0.1137 - val_loss: 2.2275 - val_accuracy: 0.1630
# Epoch 3/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.2715 - accuracy: 0.1301 - val_loss: 2.1938 - val_accuracy: 0.1887
# Epoch 4/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.2492 - accuracy: 0.1451 - val_loss: 2.1737 - val_accuracy: 0.1989
# Epoch 5/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.2262 - accuracy: 0.1531 - val_loss: 2.1451 - val_accuracy: 0.2153
# Epoch 6/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.1934 - accuracy: 0.1676 - val_loss: 2.1118 - val_accuracy: 0.2202
# Epoch 7/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.1458 - accuracy: 0.1849 - val_loss: 2.0090 - val_accuracy: 0.2643
# Epoch 8/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.0854 - accuracy: 0.2044 - val_loss: 1.9418 - val_accuracy: 0.2662
# Epoch 9/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 2.0329 - accuracy: 0.2237 - val_loss: 1.9059 - val_accuracy: 0.2813
# Epoch 10/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 1.9970 - accuracy: 0.2325 - val_loss: 1.8067 - val_accuracy: 0.3052
# Epoch 11/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 1.9158 - accuracy: 0.2619 - val_loss: 1.6699 - val_accuracy: 0.3936
# Epoch 12/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 1.7937 - accuracy: 0.3160 - val_loss: 1.5757 - val_accuracy: 0.4450
# Epoch 13/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.7259 - accuracy: 0.3494 - val_loss: 1.5065 - val_accuracy: 0.4654
# Epoch 14/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.6728 - accuracy: 0.3725 - val_loss: 1.4493 - val_accuracy: 0.4884
# Epoch 15/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.6027 - accuracy: 0.4062 - val_loss: 1.3760 - val_accuracy: 0.5215
# Epoch 16/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.5600 - accuracy: 0.4272 - val_loss: 1.3395 - val_accuracy: 0.5287
# Epoch 17/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.5087 - accuracy: 0.4453 - val_loss: 1.3020 - val_accuracy: 0.5510
# Epoch 18/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.4625 - accuracy: 0.4693 - val_loss: 1.2519 - val_accuracy: 0.5641
# Epoch 19/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.4099 - accuracy: 0.4889 - val_loss: 1.2249 - val_accuracy: 0.5750
# Epoch 20/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 1.3767 - accuracy: 0.5052 - val_loss: 1.1986 - val_accuracy: 0.5799
# Epoch 21/30
# 50000/50000 [==============================] - 86s 2ms/step - loss: 1.3337 - accuracy: 0.5212 - val_loss: 1.1515 - val_accuracy: 0.6020
# Epoch 22/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.3020 - accuracy: 0.5340 - val_loss: 1.1318 - val_accuracy: 0.6109
# Epoch 23/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.2759 - accuracy: 0.5470 - val_loss: 1.1201 - val_accuracy: 0.6156
# Epoch 24/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.2449 - accuracy: 0.5537 - val_loss: 1.0942 - val_accuracy: 0.6212
# Epoch 25/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.2190 - accuracy: 0.5663 - val_loss: 1.0623 - val_accuracy: 0.6323
# Epoch 26/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.1923 - accuracy: 0.5769 - val_loss: 1.0620 - val_accuracy: 0.6387
# Epoch 27/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.1711 - accuracy: 0.5849 - val_loss: 1.0355 - val_accuracy: 0.6402
# Epoch 28/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.1484 - accuracy: 0.5934 - val_loss: 1.0040 - val_accuracy: 0.6548
# Epoch 29/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.1222 - accuracy: 0.6014 - val_loss: 1.0045 - val_accuracy: 0.6551
# Epoch 30/30
# 50000/50000 [==============================] - 85s 2ms/step - loss: 1.1083 - accuracy: 0.6058 - val_loss: 0.9823 - val_accuracy: 0.6629

# %% [markdown]
# ### RmsProp, AdaGrad, Adam Optimizer Comparision

# %%
rms_prop_his = rmsprop_cnn.history.history['val_accuracy']
adagrad_cnn_his = adagrad_cnn.history.history['val_accuracy']
adam_cnn_his = adam_cnn.history.history['val_accuracy']
epochs = range(1, len(rms_prop_his) + 1)
# plt.figure(figsize=(20,10))
plt.plot(epochs, rms_prop_his, 'r', label='Rmsprop optimizer validation acc')
plt.plot(epochs, adagrad_cnn_his, 'y', label='Adagrad optimizer validation acc')
plt.plot(epochs, adam_cnn_his, 'g', label='Adam optimizer validation acc')
plt.title('Rmsprop vs Adagrad vs Adam validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
# plt.savefig('optimizer_validation_accuracy_comparision')
plt.show()

# %%
rms_prop_his = rmsprop_cnn.history.history['loss']
adagrad_cnn_his = adagrad_cnn.history.history['loss']
adam_cnn_his = adam_cnn.history.history['loss']
epochs = range(1, len(rms_prop_his) + 1)
# plt.figure(figsize=(20,10))
plt.plot(epochs, rms_prop_his, 'r', label='Rmsprop optimizer training loss')
plt.plot(epochs, adagrad_cnn_his, 'y', label='Adagrad optimizer training loss')
plt.plot(epochs, adam_cnn_his, 'g', label='Adam optimizer training loss')
plt.title('Rmsprop vs Adagrad vs Adam training loss accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
# plt.savefig('optimizer_training_loss_comparision')
plt.show()

# %% [markdown]
# # CNN Architecture and Training

# %% [markdown]
# ### First architecture ( 2 Conv Layer, 2 Pooling Layer, Dense NN )

# %%
structure = [
    ('conv',32),
    ('pool',2),
    ('conv',64),
    ('pool',2),
    ('dense',512)
]

# %%
call_back = TimingCallback()
cifar10_cnn = CNN(x_train,y_train,x_test,y_test)
cifar10_cnn.set_architecture(structure,batch_normalization=True,activation='relu',learning_optimizer='rmsprop')
cifar10_cnn.compile(batch_size=100,epochs=100,call_back=call_back)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 138s 3ms/step - loss: 2.0792 - accuracy: 0.3272 - val_loss: 1.4817 - val_accuracy: 0.4804
# Epoch 2/100
# 50000/50000 [==============================] - 138s 3ms/step - loss: 1.5724 - accuracy: 0.4449 - val_loss: 1.2992 - val_accuracy: 0.5423
# Epoch 3/100
# 50000/50000 [==============================] - 138s 3ms/step - loss: 1.4172 - accuracy: 0.5013 - val_loss: 1.2054 - val_accuracy: 0.5771
# Epoch 4/100
# 50000/50000 [==============================] - 143s 3ms/step - loss: 1.3205 - accuracy: 0.5344 - val_loss: 1.1704 - val_accuracy: 0.5925
# Epoch 5/100
# 50000/50000 [==============================] - 146s 3ms/step - loss: 1.2444 - accuracy: 0.5641 - val_loss: 1.0579 - val_accuracy: 0.6318
# Epoch 6/100
# 50000/50000 [==============================] - 142s 3ms/step - loss: 1.1863 - accuracy: 0.5834 - val_loss: 1.0238 - val_accuracy: 0.6435
# Epoch 7/100
# 50000/50000 [==============================] - 140s 3ms/step - loss: 1.1338 - accuracy: 0.6024 - val_loss: 1.0071 - val_accuracy: 0.6502
# Epoch 8/100
# 50000/50000 [==============================] - 140s 3ms/step - loss: 1.0973 - accuracy: 0.6174 - val_loss: 1.0163 - val_accuracy: 0.6474
# Epoch 9/100
# 50000/50000 [==============================] - 141s 3ms/step - loss: 1.0579 - accuracy: 0.6308 - val_loss: 0.9378 - val_accuracy: 0.6723
# Epoch 10/100
# 50000/50000 [==============================] - 127s 3ms/step - loss: 1.0215 - accuracy: 0.6444 - val_loss: 0.9576 - val_accuracy: 0.6718
# Epoch 11/100
# 50000/50000 [==============================] - 126s 3ms/step - loss: 0.9917 - accuracy: 0.6546 - val_loss: 0.9244 - val_accuracy: 0.6810
# Epoch 12/100
# 50000/50000 [==============================] - 121s 2ms/step - loss: 0.9616 - accuracy: 0.6669 - val_loss: 0.8987 - val_accuracy: 0.6872
# Epoch 13/100
# 50000/50000 [==============================] - 120s 2ms/step - loss: 0.9393 - accuracy: 0.6747 - val_loss: 0.9277 - val_accuracy: 0.6807
# Epoch 14/100
# 50000/50000 [==============================] - 122s 2ms/step - loss: 0.9160 - accuracy: 0.6811 - val_loss: 0.8933 - val_accuracy: 0.6911
# Epoch 15/100
# 50000/50000 [==============================] - 124s 2ms/step - loss: 0.8929 - accuracy: 0.6896 - val_loss: 0.8668 - val_accuracy: 0.7052
# Epoch 16/100
# 50000/50000 [==============================] - 127s 3ms/step - loss: 0.8752 - accuracy: 0.6973 - val_loss: 0.8297 - val_accuracy: 0.7146
# Epoch 17/100
# 50000/50000 [==============================] - 125s 3ms/step - loss: 0.8548 - accuracy: 0.7027 - val_loss: 0.8974 - val_accuracy: 0.6921
# Epoch 18/100
# 50000/50000 [==============================] - 121s 2ms/step - loss: 0.8360 - accuracy: 0.7099 - val_loss: 0.9075 - val_accuracy: 0.6914
# Epoch 19/100
# 50000/50000 [==============================] - 122s 2ms/step - loss: 0.8187 - accuracy: 0.7171 - val_loss: 0.8114 - val_accuracy: 0.7229
# Epoch 20/100
# 50000/50000 [==============================] - 121s 2ms/step - loss: 0.7966 - accuracy: 0.7213 - val_loss: 0.8205 - val_accuracy: 0.7214
# Epoch 21/100
# 50000/50000 [==============================] - 123s 2ms/step - loss: 0.7857 - accuracy: 0.7265 - val_loss: 0.8136 - val_accuracy: 0.7226
# Epoch 22/100
# 50000/50000 [==============================] - 120s 2ms/step - loss: 0.7711 - accuracy: 0.7328 - val_loss: 0.8321 - val_accuracy: 0.7171
# Epoch 23/100
# 50000/50000 [==============================] - 118s 2ms/step - loss: 0.7588 - accuracy: 0.7381 - val_loss: 0.8128 - val_accuracy: 0.7205
# Epoch 24/100
# 50000/50000 [==============================] - 118s 2ms/step - loss: 0.7377 - accuracy: 0.7445 - val_loss: 0.7999 - val_accuracy: 0.7323
# Epoch 25/100
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.7276 - accuracy: 0.7476 - val_loss: 0.7883 - val_accuracy: 0.7330
# Epoch 26/100
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.7105 - accuracy: 0.7531 - val_loss: 0.7757 - val_accuracy: 0.7339
# Epoch 27/100
# 50000/50000 [==============================] - 118s 2ms/step - loss: 0.7054 - accuracy: 0.7546 - val_loss: 0.8073 - val_accuracy: 0.7306
# Epoch 28/100
# 50000/50000 [==============================] - 120s 2ms/step - loss: 0.6940 - accuracy: 0.7609 - val_loss: 0.7858 - val_accuracy: 0.7348
# Epoch 29/100
# 50000/50000 [==============================] - 122s 2ms/step - loss: 0.6847 - accuracy: 0.7627 - val_loss: 0.8228 - val_accuracy: 0.7278
# Epoch 30/100
# 50000/50000 [==============================] - 121s 2ms/step - loss: 0.6735 - accuracy: 0.7673 - val_loss: 0.7536 - val_accuracy: 0.7474
# Epoch 31/100
# 50000/50000 [==============================] - 120s 2ms/step - loss: 0.6576 - accuracy: 0.7727 - val_loss: 0.7710 - val_accuracy: 0.7473
# Epoch 32/100
# 50000/50000 [==============================] - 124s 2ms/step - loss: 0.6507 - accuracy: 0.7762 - val_loss: 0.8154 - val_accuracy: 0.7222
# Epoch 33/100
# 50000/50000 [==============================] - 121s 2ms/step - loss: 0.6416 - accuracy: 0.7778 - val_loss: 0.7864 - val_accuracy: 0.7352
# Epoch 34/100
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.6335 - accuracy: 0.7821 - val_loss: 0.7434 - val_accuracy: 0.7497
# Epoch 35/100
# 50000/50000 [==============================] - 120s 2ms/step - loss: 0.6194 - accuracy: 0.7826 - val_loss: 0.7886 - val_accuracy: 0.7362
# Epoch 36/100
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.6175 - accuracy: 0.7858 - val_loss: 0.7760 - val_accuracy: 0.7459
# Epoch 37/100
# 50000/50000 [==============================] - 125s 3ms/step - loss: 0.6033 - accuracy: 0.7919 - val_loss: 0.7610 - val_accuracy: 0.7482
# Epoch 38/100
# 50000/50000 [==============================] - 121s 2ms/step - loss: 0.6004 - accuracy: 0.7923 - val_loss: 0.7710 - val_accuracy: 0.7429
# Epoch 39/100
# 50000/50000 [==============================] - 124s 2ms/step - loss: 0.5876 - accuracy: 0.7962 - val_loss: 0.7414 - val_accuracy: 0.7516
# Epoch 40/100
# 50000/50000 [==============================] - 126s 3ms/step - loss: 0.5847 - accuracy: 0.7984 - val_loss: 0.7468 - val_accuracy: 0.7515
# Epoch 41/100
# 50000/50000 [==============================] - 129s 3ms/step - loss: 0.5696 - accuracy: 0.8023 - val_loss: 0.7680 - val_accuracy: 0.7442
# Epoch 42/100
# 50000/50000 [==============================] - 123s 2ms/step - loss: 0.5677 - accuracy: 0.8042 - val_loss: 0.7475 - val_accuracy: 0.7525
# Epoch 43/100
# 50000/50000 [==============================] - 130s 3ms/step - loss: 0.5651 - accuracy: 0.8053 - val_loss: 0.7428 - val_accuracy: 0.7604
# Epoch 44/100
# 50000/50000 [==============================] - 128s 3ms/step - loss: 0.5552 - accuracy: 0.8083 - val_loss: 0.7440 - val_accuracy: 0.7510
# Epoch 45/100
# 50000/50000 [==============================] - 123s 2ms/step - loss: 0.5483 - accuracy: 0.8117 - val_loss: 0.7266 - val_accuracy: 0.7604
# Epoch 46/100
# 50000/50000 [==============================] - 123s 2ms/step - loss: 0.5488 - accuracy: 0.8108 - val_loss: 0.7290 - val_accuracy: 0.7585
# Epoch 47/100
# 50000/50000 [==============================] - 128s 3ms/step - loss: 0.5337 - accuracy: 0.8168 - val_loss: 0.7387 - val_accuracy: 0.7586
# Epoch 48/100
# 50000/50000 [==============================] - 123s 2ms/step - loss: 0.5329 - accuracy: 0.8178 - val_loss: 0.7763 - val_accuracy: 0.7456
# Epoch 49/100
# 50000/50000 [==============================] - 120s 2ms/step - loss: 0.5251 - accuracy: 0.8189 - val_loss: 0.7638 - val_accuracy: 0.7499
# Epoch 50/100
# 50000/50000 [==============================] - 118s 2ms/step - loss: 0.5233 - accuracy: 0.8202 - val_loss: 0.7215 - val_accuracy: 0.7649
# Epoch 51/100
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.5092 - accuracy: 0.8243 - val_loss: 0.7429 - val_accuracy: 0.7584
# Epoch 52/100
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.5096 - accuracy: 0.8261 - val_loss: 0.7351 - val_accuracy: 0.7595
# Epoch 53/100
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.4990 - accuracy: 0.8289 - val_loss: 0.7386 - val_accuracy: 0.7598
# Epoch 54/100
# 50000/50000 [==============================] - 118s 2ms/step - loss: 0.4955 - accuracy: 0.8303 - val_loss: 0.7400 - val_accuracy: 0.7570
# Epoch 55/100
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.4917 - accuracy: 0.8312 - val_loss: 0.7686 - val_accuracy: 0.7537
# Epoch 56/100
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.4887 - accuracy: 0.8330 - val_loss: 0.7575 - val_accuracy: 0.7507
# Epoch 57/100
# 50000/50000 [==============================] - 128s 3ms/step - loss: 0.4814 - accuracy: 0.8346 - val_loss: 0.7540 - val_accuracy: 0.7549
# Epoch 58/100
# 50000/50000 [==============================] - 138s 3ms/step - loss: 0.4722 - accuracy: 0.8376 - val_loss: 0.7227 - val_accuracy: 0.7643
# Epoch 59/100
# 50000/50000 [==============================] - 143s 3ms/step - loss: 0.4682 - accuracy: 0.8398 - val_loss: 0.7328 - val_accuracy: 0.7605
# Epoch 60/100
# 50000/50000 [==============================] - 142s 3ms/step - loss: 0.4674 - accuracy: 0.8397 - val_loss: 0.7397 - val_accuracy: 0.7589
# Epoch 61/100
# 50000/50000 [==============================] - 133s 3ms/step - loss: 0.4608 - accuracy: 0.8427 - val_loss: 0.7333 - val_accuracy: 0.7637
# Epoch 62/100
# 50000/50000 [==============================] - 127s 3ms/step - loss: 0.4562 - accuracy: 0.8433 - val_loss: 0.7461 - val_accuracy: 0.7559
# Epoch 63/100
# 50000/50000 [==============================] - 127s 3ms/step - loss: 0.4527 - accuracy: 0.8460 - val_loss: 0.7377 - val_accuracy: 0.7570
# Epoch 64/100
# 50000/50000 [==============================] - 124s 2ms/step - loss: 0.4508 - accuracy: 0.8444 - val_loss: 0.7427 - val_accuracy: 0.7553
# Epoch 65/100
# 50000/50000 [==============================] - 125s 3ms/step - loss: 0.4439 - accuracy: 0.8486 - val_loss: 0.7373 - val_accuracy: 0.7560
# Epoch 66/100
# 50000/50000 [==============================] - 134s 3ms/step - loss: 0.4364 - accuracy: 0.8511 - val_loss: 0.7739 - val_accuracy: 0.7492
# Epoch 67/100
# 50000/50000 [==============================] - 128s 3ms/step - loss: 0.4387 - accuracy: 0.8499 - val_loss: 0.7324 - val_accuracy: 0.7606
# Epoch 68/100
# 50000/50000 [==============================] - 126s 3ms/step - loss: 0.4320 - accuracy: 0.8529 - val_loss: 0.7430 - val_accuracy: 0.7576
# Epoch 69/100
# 50000/50000 [==============================] - 127s 3ms/step - loss: 0.4314 - accuracy: 0.8537 - val_loss: 0.7607 - val_accuracy: 0.7519
# Epoch 70/100
# 50000/50000 [==============================] - 126s 3ms/step - loss: 0.4227 - accuracy: 0.8564 - val_loss: 0.7511 - val_accuracy: 0.7544
# Epoch 71/100
# 50000/50000 [==============================] - 120s 2ms/step - loss: 0.4177 - accuracy: 0.8561 - val_loss: 0.7359 - val_accuracy: 0.7637
# Epoch 72/100
# 50000/50000 [==============================] - 125s 3ms/step - loss: 0.4175 - accuracy: 0.8566 - val_loss: 0.7276 - val_accuracy: 0.7652
# Epoch 73/100
# 50000/50000 [==============================] - 121s 2ms/step - loss: 0.4135 - accuracy: 0.8583 - val_loss: 0.7462 - val_accuracy: 0.7563
# Epoch 74/100
# 50000/50000 [==============================] - 128s 3ms/step - loss: 0.4117 - accuracy: 0.8605 - val_loss: 0.7368 - val_accuracy: 0.7650
# Epoch 75/100
# 50000/50000 [==============================] - 128s 3ms/step - loss: 0.4061 - accuracy: 0.8631 - val_loss: 0.7359 - val_accuracy: 0.7606
# Epoch 76/100
# 50000/50000 [==============================] - 131s 3ms/step - loss: 0.4012 - accuracy: 0.8638 - val_loss: 0.7429 - val_accuracy: 0.7631
# Epoch 77/100
# 50000/50000 [==============================] - 127s 3ms/step - loss: 0.4039 - accuracy: 0.8628 - val_loss: 0.8314 - val_accuracy: 0.7298
# Epoch 78/100
# 50000/50000 [==============================] - 127s 3ms/step - loss: 0.3952 - accuracy: 0.8654 - val_loss: 0.7486 - val_accuracy: 0.7552
# Epoch 79/100
# 50000/50000 [==============================] - 122s 2ms/step - loss: 0.3908 - accuracy: 0.8662 - val_loss: 0.7346 - val_accuracy: 0.7618
# Epoch 80/100
# 50000/50000 [==============================] - 127s 3ms/step - loss: 0.3874 - accuracy: 0.8692 - val_loss: 0.7675 - val_accuracy: 0.7564
# Epoch 81/100
# 50000/50000 [==============================] - 122s 2ms/step - loss: 0.3919 - accuracy: 0.8688 - val_loss: 0.7238 - val_accuracy: 0.7689
# Epoch 82/100
# 50000/50000 [==============================] - 118s 2ms/step - loss: 0.3853 - accuracy: 0.8687 - val_loss: 0.7549 - val_accuracy: 0.7542
# Epoch 83/100
# 50000/50000 [==============================] - 121s 2ms/step - loss: 0.3838 - accuracy: 0.8701 - val_loss: 0.7302 - val_accuracy: 0.7711
# Epoch 84/100
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.3784 - accuracy: 0.8712 - val_loss: 0.7372 - val_accuracy: 0.7625
# Epoch 85/100
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.3767 - accuracy: 0.8730 - val_loss: 0.7263 - val_accuracy: 0.7686
# Epoch 86/100
# 50000/50000 [==============================] - 117s 2ms/step - loss: 0.3681 - accuracy: 0.8735 - val_loss: 0.7414 - val_accuracy: 0.7626
# Epoch 87/100
# 50000/50000 [==============================] - 118s 2ms/step - loss: 0.3697 - accuracy: 0.8732 - val_loss: 0.7255 - val_accuracy: 0.7657
# Epoch 88/100
# 50000/50000 [==============================] - 118s 2ms/step - loss: 0.3658 - accuracy: 0.8756 - val_loss: 0.7343 - val_accuracy: 0.7606
# Epoch 89/100
# 50000/50000 [==============================] - 120s 2ms/step - loss: 0.3628 - accuracy: 0.8780 - val_loss: 0.7498 - val_accuracy: 0.7586
# Epoch 90/100
# 50000/50000 [==============================] - 126s 3ms/step - loss: 0.3603 - accuracy: 0.8764 - val_loss: 0.7242 - val_accuracy: 0.7645
# Epoch 91/100
# 50000/50000 [==============================] - 120s 2ms/step - loss: 0.3582 - accuracy: 0.8773 - val_loss: 0.7258 - val_accuracy: 0.7677
# Epoch 92/100
# 50000/50000 [==============================] - 121s 2ms/step - loss: 0.3507 - accuracy: 0.8813 - val_loss: 0.7703 - val_accuracy: 0.7542
# Epoch 93/100
# 50000/50000 [==============================] - 119s 2ms/step - loss: 0.3522 - accuracy: 0.8814 - val_loss: 0.7402 - val_accuracy: 0.7639
# Epoch 94/100
# 50000/50000 [==============================] - 121s 2ms/step - loss: 0.3480 - accuracy: 0.8813 - val_loss: 0.7210 - val_accuracy: 0.7655
# Epoch 95/100
# 50000/50000 [==============================] - 132s 3ms/step - loss: 0.3455 - accuracy: 0.8821 - val_loss: 0.7245 - val_accuracy: 0.7665
# Epoch 96/100
# 50000/50000 [==============================] - 124s 2ms/step - loss: 0.3398 - accuracy: 0.8857 - val_loss: 0.7868 - val_accuracy: 0.7554
# Epoch 97/100
# 50000/50000 [==============================] - 124s 2ms/step - loss: 0.3423 - accuracy: 0.8836 - val_loss: 0.7312 - val_accuracy: 0.7650
# Epoch 98/100
# 50000/50000 [==============================] - 123s 2ms/step - loss: 0.3435 - accuracy: 0.8842 - val_loss: 0.7337 - val_accuracy: 0.7673
# Epoch 99/100
# 50000/50000 [==============================] - 123s 2ms/step - loss: 0.3418 - accuracy: 0.8844 - val_loss: 0.7521 - val_accuracy: 0.7582
# Epoch 100/100
# 50000/50000 [==============================] - 130s 3ms/step - loss: 0.3322 - accuracy: 0.8856 - val_loss: 0.7765 - val_accuracy: 0.7536

# %%
loss = cifar10_cnn.history.history['loss']
val_loss = cifar10_cnn.history.history['val_loss']
epochs = range(1, len(loss) + 1)
# plt.figure(figsize=(20,10))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss for (2 Conv, 2 Pool, Dense NN)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
# plt.savefig('training_validation_loss_structure_1')
plt.show()

# %%
acc = cifar10_cnn.history.history['accuracy']
val_acc = cifar10_cnn.history.history['val_accuracy']
# plt.figure(figsize=(20,10))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy for (2 Conv, 2 Pool, Dense NN)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
# plt.savefig('training_validaton_acc_structure_1')
plt.show()

# %% [markdown]
# ### First architecture ( 4 Conv Layer, 2 Pooling Layer, Dense NN )

# %%
structure = [
    ('conv',32),
    ('conv',32),
    ('pool',2),
    ('conv',64),
    ('conv',64),
    ('pool',2),
    ('dense',512)
]

# %%
call_back = TimingCallback()
cifar10_cnn_2 = CNN(x_train,y_train,x_test,y_test)
cifar10_cnn_2.set_architecture(structure,batch_normalization=True,activation='relu',learning_optimizer='rmsprop')
cifar10_cnn_2.compile(batch_size=100,epochs=100,call_back=call_back)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 248s 5ms/step - loss: 2.2076 - accuracy: 0.2840 - val_loss: 1.5659 - val_accuracy: 0.4413
# Epoch 2/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 1.6425 - accuracy: 0.4102 - val_loss: 1.4137 - val_accuracy: 0.4983
# Epoch 3/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 1.4686 - accuracy: 0.4722 - val_loss: 1.3884 - val_accuracy: 0.5185
# Epoch 4/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 1.3729 - accuracy: 0.5078 - val_loss: 1.2431 - val_accuracy: 0.5757
# Epoch 5/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 1.2900 - accuracy: 0.5407 - val_loss: 1.1370 - val_accuracy: 0.6040
# Epoch 6/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 1.2223 - accuracy: 0.5676 - val_loss: 1.1088 - val_accuracy: 0.6123
# Epoch 7/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 1.1616 - accuracy: 0.5902 - val_loss: 1.0726 - val_accuracy: 0.6308
# Epoch 8/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 1.1050 - accuracy: 0.6076 - val_loss: 1.0089 - val_accuracy: 0.6500
# Epoch 9/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 1.0559 - accuracy: 0.6273 - val_loss: 0.9454 - val_accuracy: 0.6714
# Epoch 10/100
# 50000/50000 [==============================] - 260s 5ms/step - loss: 1.0101 - accuracy: 0.6439 - val_loss: 0.9236 - val_accuracy: 0.6787
# Epoch 11/100
# 50000/50000 [==============================] - 252s 5ms/step - loss: 0.9739 - accuracy: 0.6573 - val_loss: 0.9139 - val_accuracy: 0.6815
# Epoch 12/100
# 50000/50000 [==============================] - 255s 5ms/step - loss: 0.9403 - accuracy: 0.6707 - val_loss: 0.8553 - val_accuracy: 0.7053
# Epoch 13/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 0.9094 - accuracy: 0.6789 - val_loss: 0.8679 - val_accuracy: 0.7049
# Epoch 14/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 0.8812 - accuracy: 0.6892 - val_loss: 0.8248 - val_accuracy: 0.7160
# Epoch 15/100
# 50000/50000 [==============================] - 247s 5ms/step - loss: 0.8575 - accuracy: 0.6992 - val_loss: 0.8419 - val_accuracy: 0.7131
# Epoch 16/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 0.8318 - accuracy: 0.7081 - val_loss: 0.7945 - val_accuracy: 0.7278
# Epoch 17/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 0.8125 - accuracy: 0.7127 - val_loss: 0.7952 - val_accuracy: 0.7274
# Epoch 18/100
# 50000/50000 [==============================] - 247s 5ms/step - loss: 0.7945 - accuracy: 0.7181 - val_loss: 0.7868 - val_accuracy: 0.7302
# Epoch 19/100
# 50000/50000 [==============================] - 247s 5ms/step - loss: 0.7716 - accuracy: 0.7295 - val_loss: 0.7628 - val_accuracy: 0.7426
# Epoch 20/100
# 50000/50000 [==============================] - 247s 5ms/step - loss: 0.7571 - accuracy: 0.7329 - val_loss: 0.7658 - val_accuracy: 0.7359
# Epoch 21/100
# 50000/50000 [==============================] - 247s 5ms/step - loss: 0.7368 - accuracy: 0.7401 - val_loss: 0.7414 - val_accuracy: 0.7468
# Epoch 22/100
# 50000/50000 [==============================] - 246s 5ms/step - loss: 0.7217 - accuracy: 0.7468 - val_loss: 0.7182 - val_accuracy: 0.7542
# Epoch 23/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.7134 - accuracy: 0.7487 - val_loss: 0.7266 - val_accuracy: 0.7497
# Epoch 24/100
# 50000/50000 [==============================] - 259s 5ms/step - loss: 0.6946 - accuracy: 0.7561 - val_loss: 0.7187 - val_accuracy: 0.7564
# Epoch 25/100
# 50000/50000 [==============================] - 254s 5ms/step - loss: 0.6745 - accuracy: 0.7623 - val_loss: 0.7100 - val_accuracy: 0.7568
# Epoch 26/100
# 50000/50000 [==============================] - 256s 5ms/step - loss: 0.6669 - accuracy: 0.7651 - val_loss: 0.7113 - val_accuracy: 0.7601
# Epoch 27/100
# 50000/50000 [==============================] - 252s 5ms/step - loss: 0.6549 - accuracy: 0.7702 - val_loss: 0.6893 - val_accuracy: 0.7653
# Epoch 28/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.6467 - accuracy: 0.7725 - val_loss: 0.6732 - val_accuracy: 0.7730
# Epoch 29/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 0.6354 - accuracy: 0.7779 - val_loss: 0.6997 - val_accuracy: 0.7662
# Epoch 30/100
# 50000/50000 [==============================] - 248s 5ms/step - loss: 0.6258 - accuracy: 0.7797 - val_loss: 0.6841 - val_accuracy: 0.7634
# Epoch 31/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 0.6099 - accuracy: 0.7843 - val_loss: 0.6856 - val_accuracy: 0.7713
# Epoch 32/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 0.5989 - accuracy: 0.7874 - val_loss: 0.6938 - val_accuracy: 0.7618
# Epoch 33/100
# 50000/50000 [==============================] - 248s 5ms/step - loss: 0.5925 - accuracy: 0.7920 - val_loss: 0.6553 - val_accuracy: 0.7772
# Epoch 34/100
# 50000/50000 [==============================] - 247s 5ms/step - loss: 0.5839 - accuracy: 0.7946 - val_loss: 0.6697 - val_accuracy: 0.7740
# Epoch 35/100
# 50000/50000 [==============================] - 248s 5ms/step - loss: 0.5751 - accuracy: 0.7980 - val_loss: 0.6524 - val_accuracy: 0.7740
# Epoch 36/100
# 50000/50000 [==============================] - 247s 5ms/step - loss: 0.5652 - accuracy: 0.7998 - val_loss: 0.6440 - val_accuracy: 0.7808
# Epoch 37/100
# 50000/50000 [==============================] - 247s 5ms/step - loss: 0.5502 - accuracy: 0.8062 - val_loss: 0.6367 - val_accuracy: 0.7822
# Epoch 38/100
# 50000/50000 [==============================] - 254s 5ms/step - loss: 0.5513 - accuracy: 0.8064 - val_loss: 0.6440 - val_accuracy: 0.7841
# Epoch 39/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 0.5346 - accuracy: 0.8114 - val_loss: 0.6418 - val_accuracy: 0.7818
# Epoch 40/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 0.5243 - accuracy: 0.8167 - val_loss: 0.6300 - val_accuracy: 0.7847
# Epoch 41/100
# 50000/50000 [==============================] - 253s 5ms/step - loss: 0.5237 - accuracy: 0.8154 - val_loss: 0.6325 - val_accuracy: 0.7859
# Epoch 42/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 0.5155 - accuracy: 0.8191 - val_loss: 0.6471 - val_accuracy: 0.7886
# Epoch 43/100
# 50000/50000 [==============================] - 248s 5ms/step - loss: 0.5093 - accuracy: 0.8214 - val_loss: 0.6285 - val_accuracy: 0.7878
# Epoch 44/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 0.5033 - accuracy: 0.8234 - val_loss: 0.6339 - val_accuracy: 0.7888
# Epoch 45/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.4922 - accuracy: 0.8266 - val_loss: 0.6475 - val_accuracy: 0.7853
# Epoch 46/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 0.4852 - accuracy: 0.8288 - val_loss: 0.6372 - val_accuracy: 0.7894
# Epoch 47/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.4855 - accuracy: 0.8301 - val_loss: 0.6327 - val_accuracy: 0.7871
# Epoch 48/100
# 50000/50000 [==============================] - 252s 5ms/step - loss: 0.4727 - accuracy: 0.8342 - val_loss: 0.6226 - val_accuracy: 0.7899
# Epoch 49/100
# 50000/50000 [==============================] - 256s 5ms/step - loss: 0.4696 - accuracy: 0.8358 - val_loss: 0.6214 - val_accuracy: 0.7922
# Epoch 50/100
# 50000/50000 [==============================] - 254s 5ms/step - loss: 0.4604 - accuracy: 0.8390 - val_loss: 0.6272 - val_accuracy: 0.7903
# Epoch 51/100
# 50000/50000 [==============================] - 254s 5ms/step - loss: 0.4564 - accuracy: 0.8385 - val_loss: 0.6058 - val_accuracy: 0.7990
# Epoch 52/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.4541 - accuracy: 0.8397 - val_loss: 0.5977 - val_accuracy: 0.7971
# Epoch 53/100
# 50000/50000 [==============================] - 260s 5ms/step - loss: 0.4476 - accuracy: 0.8436 - val_loss: 0.6034 - val_accuracy: 0.7967
# Epoch 54/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.4401 - accuracy: 0.8452 - val_loss: 0.5942 - val_accuracy: 0.8001
# Epoch 55/100
# 50000/50000 [==============================] - 254s 5ms/step - loss: 0.4353 - accuracy: 0.8458 - val_loss: 0.6147 - val_accuracy: 0.7949
# Epoch 56/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 0.4315 - accuracy: 0.8502 - val_loss: 0.5975 - val_accuracy: 0.8021
# Epoch 57/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.4258 - accuracy: 0.8488 - val_loss: 0.6042 - val_accuracy: 0.8039
# Epoch 58/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 0.4229 - accuracy: 0.8507 - val_loss: 0.6039 - val_accuracy: 0.8030
# Epoch 59/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 0.4150 - accuracy: 0.8544 - val_loss: 0.6124 - val_accuracy: 0.8004
# Epoch 60/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.4106 - accuracy: 0.8556 - val_loss: 0.5987 - val_accuracy: 0.8056
# Epoch 61/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 0.4021 - accuracy: 0.8579 - val_loss: 0.5948 - val_accuracy: 0.8040
# Epoch 62/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 0.3996 - accuracy: 0.8581 - val_loss: 0.5974 - val_accuracy: 0.8051
# Epoch 63/100
# 50000/50000 [==============================] - 248s 5ms/step - loss: 0.3954 - accuracy: 0.8616 - val_loss: 0.6080 - val_accuracy: 0.7968
# Epoch 64/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.3899 - accuracy: 0.8631 - val_loss: 0.5885 - val_accuracy: 0.8040
# Epoch 65/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.3797 - accuracy: 0.8645 - val_loss: 0.6121 - val_accuracy: 0.7997
# Epoch 66/100
# 50000/50000 [==============================] - 248s 5ms/step - loss: 0.3796 - accuracy: 0.8659 - val_loss: 0.5879 - val_accuracy: 0.8077
# Epoch 67/100
# 50000/50000 [==============================] - 253s 5ms/step - loss: 0.3807 - accuracy: 0.8659 - val_loss: 0.5969 - val_accuracy: 0.8010
# Epoch 68/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.3730 - accuracy: 0.8696 - val_loss: 0.5878 - val_accuracy: 0.8066
# Epoch 69/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 0.3736 - accuracy: 0.8700 - val_loss: 0.5945 - val_accuracy: 0.8018
# Epoch 70/100
# 50000/50000 [==============================] - 257s 5ms/step - loss: 0.3632 - accuracy: 0.8723 - val_loss: 0.5979 - val_accuracy: 0.8037
# Epoch 71/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 0.3630 - accuracy: 0.8714 - val_loss: 0.5929 - val_accuracy: 0.8056
# Epoch 72/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 0.3607 - accuracy: 0.8729 - val_loss: 0.6044 - val_accuracy: 0.8066
# Epoch 73/100
# 50000/50000 [==============================] - 252s 5ms/step - loss: 0.3514 - accuracy: 0.8763 - val_loss: 0.6075 - val_accuracy: 0.8045
# Epoch 74/100
# 50000/50000 [==============================] - 252s 5ms/step - loss: 0.3501 - accuracy: 0.8774 - val_loss: 0.6093 - val_accuracy: 0.8059
# Epoch 75/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.3489 - accuracy: 0.8774 - val_loss: 0.5949 - val_accuracy: 0.8076
# Epoch 76/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 0.3430 - accuracy: 0.8813 - val_loss: 0.6007 - val_accuracy: 0.8068
# Epoch 77/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.3409 - accuracy: 0.8791 - val_loss: 0.5859 - val_accuracy: 0.8087
# Epoch 78/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.3406 - accuracy: 0.8822 - val_loss: 0.5820 - val_accuracy: 0.8108
# Epoch 79/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.3359 - accuracy: 0.8822 - val_loss: 0.5902 - val_accuracy: 0.8097
# Epoch 80/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 0.3311 - accuracy: 0.8826 - val_loss: 0.5765 - val_accuracy: 0.8143
# Epoch 81/100
# 50000/50000 [==============================] - 258s 5ms/step - loss: 0.3303 - accuracy: 0.8841 - val_loss: 0.5902 - val_accuracy: 0.8115
# Epoch 82/100
# 50000/50000 [==============================] - 254s 5ms/step - loss: 0.3236 - accuracy: 0.8850 - val_loss: 0.6015 - val_accuracy: 0.8080
# Epoch 83/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 0.3250 - accuracy: 0.8854 - val_loss: 0.6095 - val_accuracy: 0.8085
# Epoch 84/100
# 50000/50000 [==============================] - 258s 5ms/step - loss: 0.3219 - accuracy: 0.8864 - val_loss: 0.6054 - val_accuracy: 0.8038
# Epoch 85/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 0.3148 - accuracy: 0.8889 - val_loss: 0.5864 - val_accuracy: 0.8148
# Epoch 86/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 0.3168 - accuracy: 0.8883 - val_loss: 0.5916 - val_accuracy: 0.8101
# Epoch 87/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 0.3124 - accuracy: 0.8906 - val_loss: 0.5885 - val_accuracy: 0.8099
# Epoch 88/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.3089 - accuracy: 0.8905 - val_loss: 0.6052 - val_accuracy: 0.8085
# Epoch 89/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 0.3025 - accuracy: 0.8943 - val_loss: 0.6235 - val_accuracy: 0.8089
# Epoch 90/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.3031 - accuracy: 0.8939 - val_loss: 0.5879 - val_accuracy: 0.8119
# Epoch 91/100
# 50000/50000 [==============================] - 249s 5ms/step - loss: 0.3000 - accuracy: 0.8935 - val_loss: 0.6051 - val_accuracy: 0.8107
# Epoch 92/100
# 50000/50000 [==============================] - 250s 5ms/step - loss: 0.2946 - accuracy: 0.8959 - val_loss: 0.5828 - val_accuracy: 0.8132
# Epoch 93/100
# 50000/50000 [==============================] - 253s 5ms/step - loss: 0.2933 - accuracy: 0.8953 - val_loss: 0.6084 - val_accuracy: 0.8087
# Epoch 94/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 0.2938 - accuracy: 0.8991 - val_loss: 0.5761 - val_accuracy: 0.8124
# Epoch 95/100
# 50000/50000 [==============================] - 253s 5ms/step - loss: 0.2911 - accuracy: 0.8972 - val_loss: 0.5784 - val_accuracy: 0.8177
# Epoch 96/100
# 50000/50000 [==============================] - 259s 5ms/step - loss: 0.2845 - accuracy: 0.8996 - val_loss: 0.6071 - val_accuracy: 0.8119
# Epoch 97/100
# 50000/50000 [==============================] - 252s 5ms/step - loss: 0.2821 - accuracy: 0.9010 - val_loss: 0.6050 - val_accuracy: 0.8103
# Epoch 98/100
# 50000/50000 [==============================] - 256s 5ms/step - loss: 0.2841 - accuracy: 0.9000 - val_loss: 0.5814 - val_accuracy: 0.8161
# Epoch 99/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 0.2845 - accuracy: 0.9002 - val_loss: 0.5911 - val_accuracy: 0.8166
# Epoch 100/100
# 50000/50000 [==============================] - 251s 5ms/step - loss: 0.2746 - accuracy: 0.9035 - val_loss: 0.6061 - val_accuracy: 0.8132

# %%
loss = cifar10_cnn_2.history.history['loss']
val_loss = cifar10_cnn_2.history.history['val_loss']
epochs = range(1, len(loss) + 1)
# plt.figure(figsize=(20,10))
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss for (4 Conv, 2 Pool, Dense NN)') 
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
# plt.savefig('training_validation_loss_structure_2')
plt.show()

# %%
acc = cifar10_cnn_2.history.history['accuracy']
val_acc = cifar10_cnn_2.history.history['val_accuracy']
# plt.figure(figsize=(20,10))
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy for (4 Conv, 2 Pool, Dense NN)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
# plt.savefig('training_validaton_acc_structure_2')
plt.show()
